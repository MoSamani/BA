# %%
#CSV Bibliothek importieren 
import csv
#Pandas importieren und als pd bezeichnen
import pandas as pd
#Numpy importieren und als np bezeichnen 
import numpy as np
#Json Biliothek importieren
import json
#Obere Schranke für die Größe der Daten auf 100,000,000 setzen  
csv.field_size_limit(100000000)
#Maximale Anzahl von Zeilen und Spalten Zeigen 
pd.options.display.max_columns = None
pd.options.display.max_rows = None
#Seaborn für die Plots importieren
import seaborn as sns
#matplotlib für die Plots importieren
import matplotlib.pyplot as plt
#pickle wird füe das Speichern des Modells benutzt
import pickle
#Das RandomForest Modell importieren 
from sklearn.ensemble import RandomForestClassifier
#DecisionTreeClassifier importieren
from sklearn.tree import DecisionTreeClassifier
#train_test_split importieren, um die Daten für das Training und Testing teilen.
from sklearn.model_selection import train_test_split
#Die Metrik-Funktionen aus SKlearn importieren 
from sklearn.metrics import accuracy_score, confusion_matrix, r2_score, classification_report, log_loss
#cross_val_score Für die Cross Validiereung der Ergebnisse importieren
from sklearn.model_selection import cross_val_score
#Warnings zu Console umleiten
import warnings
warnings.filterwarnings("ignore")
#Die Nachkommastellen auf 4 einschränken
pd.options.display.float_format = '{:.4f}'.format
from datetime import datetime

# %% [markdown]
# # RandomForestClassifier
# ## *(1)TweetsCov19*
# ### (Ihalt- und Benutzerfeatures)

# %%
#Die Dataframe, die sowohl die Benutzer- als auch die Inhaltsfeatures enthält, wird gelesen.
pfad_tsv = 'C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_sample/Tweetscov19_sample/TweetsFormodel/tweetsCov19_sample_with_users_1_48.tsv'

df_tweetscov19_user = pd.read_csv(pfad_tsv, sep='\t', error_bad_lines=False, names=['Tweet_Id', 'Username', 'Is_deleted', 'Retweets', 'Likes', 'Stimmung', 'Hashtags', 'Mentions', 'Textlänge', 'URLs n.', 'Lesbarkeit', 'A. Emojis', 'Emoji sentiment', 'Politische P.T.', 'Wissenschaftliche P.T.', 'Moderate P.T.', 'Porn(Shalla)', 'News(Shalla)', 'Socialnet(Shalla)', 'Social', 'Family', 'Friend', 'Female', 'Male' , 'Work', 'Leisure', 'Home', 'Money', 'Relegion', 'Death', 'Informal', 'Swear', 'Netspeak', 'Assent', 'Nonfluence', 'Filler', 'Body', 'Health', 'Sexual', 'Ingest', 'Pos. emo.', 'Neg. emo.', 'Anxiety', 'Anger', 'Sadness', 'Insight', 'Cause', 'Discrep', 'Tentativness', 'Certainty', 'Differentiation', 'Affiliation', 'Achieve', 'Power', 'Reward', 'Risk', 'Focus past', 'Focus present', 'Focus future', 'I', 'We', 'You', 'SheHe', 'They', 'Ipron', 'Article', 'Preposition', 'Auxverb', 'Adverb', 'Conjunctive', 'Negate', 'Verb', 'Adjective', 'Compare', 'Interrogative', 'Number', 'Quantitative', 'See', 'Hear', 'Feel', 'Motion', 'Space', 'Time', 'Politische P.B.', 'Wissen. P.B.', 'Moderate P.B.', 'Posted n.', 'Deleted n.', 'Deletion ratio', 'Reputation' ])
pd.options.display.max_columns = None
print('Shape :', df_tweetscov19_user.shape)
df_tweetscov19_user.head()
# Out:
# Shape : (20000, 90)
#               Tweet_Id                          Username  Is_deleted  \
# 0  1247496374351994880  604ad6d57aa7e0cdecdb05b420470b11        True
# 1  1254519280063991808  636af432dc9192d910cb80f908ed3ddd        True
# 2  1222335084365275136  fcd6ec7badb73ba219a74c367e2a3bb0        True
# 3  1266089390859845632  c4fd6f9a730d278256fd08620a6e513e        True
# 4  1196450971062341632  58eb458bc750cac884e8e93bb3968ce8        True
#
#    Retweets  Likes  Stimmung  Hashtags  Mentions  Textlänge  URLs n.  \
# 0         0      0    0.0000         2         1        119        1
# 1         1      0    0.0000         1         1        144        1
# 2         0      0    0.4019         1         1        119        1
# 3        34     51   -0.7033         0         0        163        0
# 4         2      0   -0.7906         0         0        208        1
#
#    Lesbarkeit  A. Emojis  Emoji sentiment  Politische P.T.  \
# 0     46.9420          0           0.0000               -1
# 1     48.6350          0           0.0000                0
# 2     28.0500          0           0.0000                0
# 3     56.7000          0           0.0000                0
# 4     50.4010          2           0.1225                1
#
#    Wissenschaftliche P.T.  Moderate P.T.  Porn(Shalla)  News(Shalla)  \
# 0                       0              1        0.0000        0.0000
# 1                       0             -1        0.0000        1.0000
# 2                       0              0        0.0000        0.0000
# 3                       0              0        0.0000        0.0000
# 4                      -1              1        0.0000        0.0000
#
#    Socialnet(Shalla)  Social  Family  Friend  Female   Male   Work  Leisure  \
# 0             0.0000  0.0000  0.0000  0.0000  0.0000 0.0000 0.0000   0.0000
# 1             0.0000  0.0000  0.0000  0.0000  0.0000 0.0000 4.1700   0.0000
# 2             0.0000  0.0000  0.0000  0.0000  0.0000 0.0000 0.0000   0.0000
# 3             0.0000  7.6900  0.0000  0.0000  0.0000 7.6900 0.0000   0.0000
# 4             0.0000  5.5600  0.0000  0.0000  0.0000 0.0000 5.5600   0.0000
#
#     Home  Money  Relegion  Death  Informal  Swear  Netspeak  Assent  \
# 0 0.0000 5.8800    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
# 1 0.0000 4.1700    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
# 2 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
# 3 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
# 4 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000  0.0000
#
#    Nonfluence  Filler   Body  Health  Sexual  Ingest  Pos. emo.  Neg. emo.  \
# 0      0.0000  0.0000 0.0000  0.0000  0.0000  0.0000     0.0000     0.0000
# 1      0.0000  0.0000 0.0000  0.0000  0.0000  0.0000     0.0000     0.0000
# 2      0.0000  0.0000 0.0000  0.0000  0.0000  0.0000     0.0000     0.0000
# 3      0.0000  0.0000 0.0000  0.0000  0.0000  0.0000     0.0000     0.0000
# 4      0.0000  0.0000 0.0000  0.0000  0.0000  0.0000     0.0000     2.7800
#
#    Anxiety  Anger  Sadness  Insight  Cause  Discrep  Tentativness  Certainty  \
# 0   0.0000 0.0000   0.0000   0.0000 0.0000   0.0000        0.0000     5.8800
# 1   0.0000 0.0000   0.0000   4.1700 4.1700   4.1700        4.1700     4.1700
# 2   0.0000 0.0000   0.0000   0.0000 5.2600   0.0000        0.0000     0.0000
# 3   0.0000 0.0000   0.0000   0.0000 0.0000   0.0000        0.0000     0.0000
# 4   0.0000 0.0000   2.7800   0.0000 0.0000   0.0000        0.0000     0.0000
#
#    Differentiation  Affiliation  Achieve  Power  Reward   Risk  Focus past  \
# 0           0.0000       0.0000   0.0000 0.0000  0.0000 0.0000      0.0000
# 1           4.1700       0.0000   4.1700 0.0000  4.1700 0.0000      4.1700
# 2           0.0000       0.0000   0.0000 0.0000  0.0000 0.0000      0.0000
# 3           0.0000       0.0000   0.0000 0.0000  0.0000 0.0000      3.8500
# 4           0.0000       2.7800   2.7800 2.7800  0.0000 2.7800      0.0000
#
#    Focus present  Focus future      I     We    You  SheHe   They  Ipron  \
# 0         0.0000        0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
# 1         4.1700        0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
# 2        10.5300        0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 5.2600
# 3         0.0000        0.0000 0.0000 0.0000 0.0000 7.6900 0.0000 0.0000
# 4         2.7800        0.0000 0.0000 2.7800 0.0000 0.0000 0.0000 2.7800
#
#    Article  Preposition  Auxverb  Adverb  Conjunctive  Negate    Verb  \
# 0   5.8800      11.7600   0.0000  0.0000       0.0000  0.0000  0.0000
# 1   0.0000      12.5000   0.0000  0.0000       8.3300  0.0000  8.3300
# 2   0.0000      15.7900   0.0000  0.0000       0.0000  0.0000 10.5300
# 3   7.6900       3.8500   0.0000  0.0000       0.0000  0.0000  3.8500
# 4   2.7800      13.8900   2.7800  0.0000       0.0000  0.0000  5.5600
#
#    Adjective  Compare  Interrogative  Number  Quantitative    See   Hear  \
# 0     0.0000   0.0000         0.0000  0.0000        5.8800 0.0000 0.0000
# 1     8.3300   8.3300         0.0000  0.0000        4.1700 0.0000 0.0000
# 2     0.0000   0.0000         0.0000  0.0000        0.0000 0.0000 0.0000
# 3     0.0000   0.0000         0.0000  0.0000        0.0000 0.0000 0.0000
# 4     0.0000   0.0000         2.7800  0.0000        0.0000 0.0000 0.0000
#
#     Feel  Motion  Space    Time  Politische P.B.  Wissen. P.B.  Moderate P.B.  \
# 0 0.0000  0.0000 5.8800  5.8800           0.4286       -0.1429         0.2000
# 1 0.0000  0.0000 8.3300  4.1700           0.6364       -0.0476         0.5714
# 2 0.0000  0.0000 5.2600  0.0000           1.0000       -1.0000         1.0000
# 3 0.0000  0.0000 3.8500 11.5400           1.0000       -1.0000         1.0000
# 4 0.0000  0.0000 2.7800  2.7800           1.0000       -1.0000         1.0000
#
#    Posted n.  Deleted n.  Deletion ratio  Reputation
# 0         24          24          1.0000      0.0000
# 1         41          41          1.0000      0.4881
# 2          3           3          1.0000      0.5052
# 3         31          31          1.0000      0.7145
# 4          4           4          1.0000      0.5258

# %%
features = df_tweetscov19_user.columns
features
# Out:
# Index(['Tweet_Id', 'Username', 'Is_deleted', 'Retweets', 'Likes', 'Stimmung',
#        'Hashtags', 'Mentions', 'Textlänge', 'URLs n.', 'Lesbarkeit',
#        'A. Emojis', 'Emoji sentiment', 'Politische P.T.',
#        'Wissenschaftliche P.T.', 'Moderate P.T.', 'Porn(Shalla)',
#        'News(Shalla)', 'Socialnet(Shalla)', 'Social', 'Family', 'Friend',
#        'Female', 'Male', 'Work', 'Leisure', 'Home', 'Money', 'Relegion',
#        'Death', 'Informal', 'Swear', 'Netspeak', 'Assent', 'Nonfluence',
#        'Filler', 'Body', 'Health', 'Sexual', 'Ingest', 'Pos. emo.',
#        'Neg. emo.', 'Anxiety', 'Anger', 'Sadness', 'Insight', 'Cause',
#        'Discrep', 'Tentativness', 'Certainty', 'Differentiation',
#        'Affiliation', 'Achieve', 'Power', 'Reward', 'Risk', 'Focus past',
#        'Focus present', 'Focus future', 'I', 'We', 'You', 'SheHe', 'They',
#        'Ipron', 'Article', 'Preposition', 'Auxverb', 'Adverb', 'Conjunctive',
#        'Negate', 'Verb', 'Adjective', 'Compare', 'Interrogative', 'Number',
#        'Quantitative', 'See', 'Hear', 'Feel', 'Motion', 'Space', 'Time',
#        'Politische P.B.', 'Wissen. P.B.', 'Moderate P.B.', 'Posted n.',
#        'Deleted n.', 'Deletion ratio', 'Reputation'],
#       dtype='object')

# %%
#Die gelöscten Tweets werden mit 0 und nicht gelösschten mit 1 markieren.
df_tweetscov19_user['Is_deleted'] = np.where(df_tweetscov19_user['Is_deleted'] == True, 0, 1)
df_tweetscov19_user.tail()
# Out:
#                   Tweet_Id                          Username  Is_deleted  \
# 19995  1264046188346695681  4b289ad7423932d18b61af4f13ce90fa           1
# 19996  1238923377164902402  e1d66715bf953980a28a98539d297628           1
# 19997  1236449705875230720  3b830bcc957c025498f9c5d9880a6b16           1
# 19998  1265759231413649408  5e0d7812f8f2d82e32ec0988b45c238d           1
# 19999  1240330661011099655  0b9efa2f4775538791c7a891c7f46623           1
#
#        Retweets  Likes  Stimmung  Hashtags  Mentions  Textlänge  URLs n.  \
# 19995         5      4    0.8531         1         0        266        0
# 19996         1      0    0.0000         1         1        286        1
# 19997         0      0   -0.4215         0         0         93        0
# 19998         3      2   -0.9231         0         0        240        1
# 19999        49    102    0.5454         3         0        274        0
#
#        Lesbarkeit  A. Emojis  Emoji sentiment  Politische P.T.  \
# 19995     59.2800          0           0.0000                0
# 19996     24.0310          4           0.2273                0
# 19997     87.2840          0           0.0000                0
# 19998     49.6500          0           0.0000               -1
# 19999     92.8100          1           0.5560                0
#
#        Wissenschaftliche P.T.  Moderate P.T.  Porn(Shalla)  News(Shalla)  \
# 19995                       0              0        0.0000        0.0000
# 19996                       0              0        0.0000        0.0000
# 19997                       0              0        0.0000        0.0000
# 19998                       0             -1        0.0000        1.0000
# 19999                       0              0        0.0000        0.0000
#
#        Socialnet(Shalla)  Social  Family  Friend  Female   Male   Work  \
# 19995             0.0000  4.4400  0.0000  0.0000  0.0000 0.0000 0.0000
# 19996             0.0000 10.5300  0.0000  0.0000  0.0000 0.0000 2.6300
# 19997             0.0000  0.0000  0.0000  0.0000  0.0000 0.0000 6.2500
# 19998             0.0000  0.0000  0.0000  0.0000  0.0000 0.0000 0.0000
# 19999             0.0000  8.3300  0.0000  0.0000  0.0000 0.0000 0.0000
#
#        Leisure   Home  Money  Relegion  Death  Informal  Swear  Netspeak  \
# 19995   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
# 19996   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
# 19997   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
# 19998   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
# 19999   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000 0.0000    0.0000
#
#        Assent  Nonfluence  Filler   Body  Health  Sexual  Ingest  Pos. emo.  \
# 19995  0.0000      0.0000  0.0000 0.0000  2.2200  0.0000  0.0000     2.2200
# 19996  0.0000      0.0000  0.0000 0.0000  2.6300  0.0000  0.0000     2.6300
# 19997  0.0000      0.0000  0.0000 0.0000  0.0000  0.0000  0.0000     0.0000
# 19998  0.0000      0.0000  0.0000 0.0000  2.5600  0.0000  0.0000     0.0000
# 19999  0.0000      0.0000  0.0000 0.0000  0.0000  0.0000  0.0000     0.0000
#
#        Neg. emo.  Anxiety  Anger  Sadness  Insight  Cause  Discrep  \
# 19995     0.0000   0.0000 0.0000   0.0000   0.0000 0.0000   2.2200
# 19996     0.0000   0.0000 0.0000   0.0000   2.6300 0.0000   0.0000
# 19997     6.2500   6.2500 0.0000   0.0000   6.2500 0.0000   0.0000
# 19998     7.6900   2.5600 0.0000   2.5600   0.0000 0.0000   0.0000
# 19999     0.0000   0.0000 0.0000   0.0000   0.0000 0.0000   2.0800
#
#        Tentativness  Certainty  Differentiation  Affiliation  Achieve  Power  \
# 19995        2.2200     0.0000           0.0000       4.4400   2.2200 0.0000
# 19996        0.0000     2.6300           0.0000       5.2600   0.0000 0.0000
# 19997        0.0000     0.0000           0.0000       0.0000   0.0000 0.0000
# 19998        0.0000     0.0000           2.5600       0.0000   0.0000 2.5600
# 19999        2.0800     4.1700           2.0800       0.0000   0.0000 0.0000
#
#        Reward   Risk  Focus past  Focus present  Focus future      I     We  \
# 19995  0.0000 0.0000      0.0000        11.1100        0.0000 0.0000 4.4400
# 19996  0.0000 0.0000      0.0000         5.2600        0.0000 0.0000 0.0000
# 19997  0.0000 0.0000      6.2500         6.2500        0.0000 0.0000 0.0000
# 19998  0.0000 0.0000      0.0000         0.0000        0.0000 0.0000 0.0000
# 19999  0.0000 0.0000      0.0000        14.5800        0.0000 0.0000 0.0000
#
#          You  SheHe   They  Ipron  Article  Preposition  Auxverb  Adverb  \
# 19995 0.0000 0.0000 0.0000 0.0000   2.2200       8.8900   8.8900  2.2200
# 19996 0.0000 0.0000 0.0000 0.0000   0.0000       7.8900   2.6300  5.2600
# 19997 0.0000 0.0000 0.0000 6.2500   6.2500       0.0000  12.5000  0.0000
# 19998 0.0000 0.0000 0.0000 2.5600   5.1300      12.8200   0.0000  0.0000
# 19999 2.0800 0.0000 0.0000 8.3300   4.1700      10.4200   4.1700  0.0000
#
#        Conjunctive  Negate    Verb  Adjective  Compare  Interrogative  Number  \
# 19995       2.2200  0.0000 15.5600     2.2200   2.2200         0.0000  2.2200
# 19996       0.0000  0.0000  2.6300     2.6300   0.0000         0.0000  0.0000
# 19997       0.0000  0.0000 12.5000     6.2500   0.0000         0.0000  0.0000
# 19998       5.1300  0.0000  0.0000     2.5600   0.0000         0.0000  2.5600
# 19999       0.0000  2.0800 14.5800     0.0000   0.0000         0.0000  0.0000
#
#        Quantitative    See   Hear   Feel  Motion  Space   Time  \
# 19995        0.0000 0.0000 0.0000 0.0000  2.2200 0.0000 4.4400
# 19996        2.6300 0.0000 0.0000 0.0000  2.6300 5.2600 5.2600
# 19997        0.0000 6.2500 0.0000 0.0000  0.0000 6.2500 0.0000
# 19998        0.0000 0.0000 0.0000 0.0000  0.0000 5.1300 0.0000
# 19999        4.1700 0.0000 2.0800 0.0000  4.1700 2.0800 0.0000
#
#        Politische P.B.  Wissen. P.B.  Moderate P.B.  Posted n.  Deleted n.  \
# 19995          -0.0142       -0.2000        -0.3289       2985           0
# 19996          -0.1429        1.0000        -0.6000         26           0
# 19997           0.0811       -0.3333        -0.2475       1185          12
# 19998          -0.6000        1.0000        -0.6000         29           0
# 19999           0.3333       -1.0000        -0.3333         23           0
#
#        Deletion ratio  Reputation
# 19995          0.0000      0.5332
# 19996          0.0000      0.9655
# 19997          0.0101      0.9945
# 19998          0.0000      0.3645
# 19999          0.0000      0.5107

# %%
#TweetId und Benutzername werden aus der Dataframe entfernt.
features = features[2:90]
print(len(features))
features
# Out:
# 88
# Index(['Is_deleted', 'Retweets', 'Likes', 'Stimmung', 'Hashtags', 'Mentions',
#        'Textlänge', 'URLs n.', 'Lesbarkeit', 'A. Emojis', 'Emoji sentiment',
#        'Politische P.T.', 'Wissenschaftliche P.T.', 'Moderate P.T.',
#        'Porn(Shalla)', 'News(Shalla)', 'Socialnet(Shalla)', 'Social', 'Family',
#        'Friend', 'Female', 'Male', 'Work', 'Leisure', 'Home', 'Money',
#        'Relegion', 'Death', 'Informal', 'Swear', 'Netspeak', 'Assent',
#        'Nonfluence', 'Filler', 'Body', 'Health', 'Sexual', 'Ingest',
#        'Pos. emo.', 'Neg. emo.', 'Anxiety', 'Anger', 'Sadness', 'Insight',
#        'Cause', 'Discrep', 'Tentativness', 'Certainty', 'Differentiation',
#        'Affiliation', 'Achieve', 'Power', 'Reward', 'Risk', 'Focus past',
#        'Focus present', 'Focus future', 'I', 'We', 'You', 'SheHe', 'They',
#        'Ipron', 'Article', 'Preposition', 'Auxverb', 'Adverb', 'Conjunctive',
#        'Negate', 'Verb', 'Adjective', 'Compare', 'Interrogative', 'Number',
#        'Quantitative', 'See', 'Hear', 'Feel', 'Motion', 'Space', 'Time',
#        'Politische P.B.', 'Wissen. P.B.', 'Moderate P.B.', 'Posted n.',
#        'Deleted n.', 'Deletion ratio', 'Reputation'],
#       dtype='object')

# %%
# Die Features, Anzahl der geposteten und gelöschten Tweets sowie Löschquote erden hier aus der Dataframe entfernt.
#Zwei Matrixen werden erzeugt. Einer beinhaltet alle Features ohne 'Ist_gelöscht' und die andere nur 'Ist_gelöscht' 

df_tweetscov19_user_2 = df_tweetscov19_user[features.tolist()]
df_tweetscov19_user_2 = df_tweetscov19_user_2.drop(columns=['Posted n.', 'Deleted n.','Deletion ratio'])
df = df_tweetscov19_user_2.drop('Is_deleted', axis=1)
X = df_tweetscov19_user_2.drop('Is_deleted', axis=1)
y = df_tweetscov19_user_2['Is_deleted']

y = y.astype(int)
print(X.shape)
print(y.shape)
# Out:
# (20000, 84)
# (20000,)

# %%
#Hier werden die Daten in zwei Teielen für das Training und Testing des Modells aufgeteilt.
def split_train_test_valid(X,y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, test_size=0.2, random_state=15)
    #X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, train_size=0.8, test_size=0.2, random_state=15)
    print(X_train.shape)
    print(X_test.shape)
    #print(X_valid.shape)

    print(y_train.shape)
    print(y_test.shape)
    #print(y_valid.shape)
    return  X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = split_train_test_valid(X,y)
# Out:
# (16000, 84)
# (4000, 84)
# (16000,)
# (4000,)

# %%
#Das Modell fiten
def fit_random_forest_clf(X,y):
    
    clf = RandomForestClassifier(n_estimators=100, random_state=0, n_jobs=-1)
    clf.fit(X,y)
    return clf

# %%
#Die Genuigkeit für die Testsergebnissen wird hier berechnet.
def test_random_forest_clf(model, X_test, y_test):
    
    y_pred = model.predict(X_test)
    print('Accuracy :', accuracy_score(y_test, y_pred))

# %%
rf_model = fit_random_forest_clf(X_train, y_train)

# %%
#Das Modell wird her gespeichert.
pfad_modell = 'C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_sample/Tweetscov19_sample/Modells/TweetsCov19_RF_Benutzer_Inhalt_alle_ohne_moderacy_2.sav'
#pickle.dump(rf_model, open(pfad_modell, 'wb'))

# %%
test_random_forest_clf(rf_model, X_test, y_test)
# Out:
# Accuracy : 0.81925

# %%
#In dieser Methode wird die Wichtigkeit der Features berechnet.
#Das Ergebnis wird in einer Dataframe gespeichert und ausgegeben.

def features_classifier_(df, model):

    column_feature = {}

    for i, c in enumerate(df):
        #print(c, '   ', decisionTC.feature_importances_[i])

        column_feature[c] = model.feature_importances_[i]
        #print(c)
    df_column_feature = pd.DataFrame(column_feature.items(), columns=['Feature','importance'])
    df_column_feature.sort_values(by = ['importance'], ascending = False, inplace = True)

    df_column_feature = df_column_feature.reset_index()
    df_column_feature
    return df_column_feature

# %%
f_importances = features_classifier_(df, rf_model)
f_importances
# Out:
#     index                 Feature  importance
# 0      83              Reputation      0.1224
# 1      80         Politische P.B.      0.0998
# 2      82           Moderate P.B.      0.0783
# 3      81            Wissen. P.B.      0.0634
# 4       1                   Likes      0.0446
# 5       0                Retweets      0.0412
# 6       7              Lesbarkeit      0.0269
# 7       5               Textlänge      0.0257
# 8       2                Stimmung      0.0224
# 9      63             Preposition      0.0212
# 10     78                   Space      0.0170
# 11     68                    Verb      0.0161
# 12     54           Focus present      0.0153
# 13     62                 Article      0.0144
# 14     16                  Social      0.0134
# 15     64                 Auxverb      0.0129
# 16     21                    Work      0.0124
# 17     50                   Power      0.0123
# 18     79                    Time      0.0120
# 19     66             Conjunctive      0.0120
# 20     61                   Ipron      0.0106
# 21     69               Adjective      0.0106
# 22     10         Politische P.T.      0.0099
# 23     65                  Adverb      0.0095
# 24      4                Mentions      0.0091
# 25      3                Hashtags      0.0090
# 26     53              Focus past      0.0088
# 27     38               Neg. emo.      0.0079
# 28     70                 Compare      0.0079
# 29     45            Tentativness      0.0075
# 30     43                   Cause      0.0075
# 31     47         Differentiation      0.0075
# 32     77                  Motion      0.0073
# 33     37               Pos. emo.      0.0072
# 34     49                 Achieve      0.0071
# 35     42                 Insight      0.0070
# 36      8               A. Emojis      0.0068
# 37     48             Affiliation      0.0068
# 38     34                  Health      0.0067
# 39     73            Quantitative      0.0067
# 40     11  Wissenschaftliche P.T.      0.0063
# 41     46               Certainty      0.0060
# 42     51                  Reward      0.0059
# 43     71           Interrogative      0.0057
# 44     44                 Discrep      0.0057
# 45     58                     You      0.0056
# 46     52                    Risk      0.0055
# 47     12           Moderate P.T.      0.0052
# 48     55            Focus future      0.0050
# 49     74                     See      0.0048
# 50     24                   Money      0.0048
# 51     67                  Negate      0.0047
# 52      9         Emoji sentiment      0.0047
# 53      6                 URLs n.      0.0046
# 54     14            News(Shalla)      0.0046
# 55     75                    Hear      0.0045
# 56     40                   Anger      0.0045
# 57     72                  Number      0.0045
# 58     22                 Leisure      0.0042
# 59     26                   Death      0.0042
# 60     59                   SheHe      0.0039
# 61     20                    Male      0.0039
# 62     57                      We      0.0039
# 63     60                    They      0.0038
# 64     23                    Home      0.0037
# 65     33                    Body      0.0036
# 66     39                 Anxiety      0.0032
# 67     41                 Sadness      0.0032
# 68     27                Informal      0.0031
# 69     76                    Feel      0.0026
# 70     36                  Ingest      0.0023
# 71     19                  Female      0.0023
# 72     56                       I      0.0023
# 73     25                Relegion      0.0019
# 74     15       Socialnet(Shalla)      0.0017
# 75     17                  Family      0.0016
# 76     18                  Friend      0.0014
# 77     29                Netspeak      0.0013
# 78     28                   Swear      0.0013
# 79     35                  Sexual      0.0010
# 80     30                  Assent      0.0008
# 81     31              Nonfluence      0.0006
# 82     32                  Filler      0.0003
# 83     13            Porn(Shalla)      0.0000

# %%
#Anhand der Testergebnisse wird ein Bericht vorbereitet und ausgegeben.
y_pred = rf_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82      2003
#            1       0.82      0.81      0.82      1997
#
#     accuracy                           0.82      4000
#    macro avg       0.82      0.82      0.82      4000
# weighted avg       0.82      0.82      0.82      4000

# %%
# confusio_matrix wird hier vorbereitet und dargestellet.
# Die Ergebnisse durch die gesammten Daten teilen, sodass das Ergebnis auf eine Zahl zwischen 0 und 1 gebildet wird.
def plot_confusion_matrix(y_test, y_pred, classes, titel):
    
    confusion_mx = confusion_matrix(y_test, y_pred)
    confusion_mx = confusion_mx / confusion_mx.sum(axis=1).reshape(-1,1)
    
    sns.heatmap(confusion_mx, xticklabels = classes, yticklabels = classes, annot=True, cmap='YlGnBu')
    plt.title(titel)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
plot_confusion_matrix(y_test, y_pred, rf_model.classes_, 'Confusion Matrix')

# %%
#Hier werden Wahrscheinlichkeiten der Ergebnisse berechnet.
#Anhand der bekommenen Wahrscheinlichkeiten berechnen wir die Log_loss.

y_prob_test = rf_model.predict_proba(X_test)
print('Logarithmic loss für Test data', log_loss(y_test, y_prob_test))
# Out:
# Logarithmic loss für Test data 0.45315237299525707

# %%
#Das Modell laden
pfad_modell = 'C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_sample/Tweetscov19_sample/Modells/Tweetscov19_RF_Benutzer_Inhalt_48.sav'
#rf_model = pickle.load(open(pfad_modell, 'rb'))

# %%
#Die Ergebnisse werden mithilfe der drei Metriken durch Kreuzverfahren berechnet. cv=10

def print_cross_val_score(model, X_test, y_test):
    scores = cross_val_score(model, X_test, y_test, cv=10, scoring='precision')
    print(" percision : %0.2f +/- %0.3f" % (scores.mean(), scores.std()))
    scores = cross_val_score(model, X_test, y_test, cv=10, scoring='f1')
    print(" f1        : %0.2f +/- %0.3f" % (scores.mean(), scores.std()))
    scores = cross_val_score(model, X_test, y_test, cv=10, scoring='recall')
    print(" recall    : %0.2f +/- %0.3f" % (scores.mean(), scores.std()))

# %%
print_cross_val_score(rf_model, X_test, y_test)
# Out:
#  percision : 0.81 +/- 0.027
#  f1        : 0.80 +/- 0.015
#  recall    : 0.80 +/- 0.014

# %% [markdown]
# ************************************************
# ************************************************

# %% [markdown]
# ### TweetsCov19
# ### Darstellung der Wichtigkeit der Features:
# #### (Ihalt- und Benutzerfeatures)

# %% [markdown]
# ****

# %%
def plot_hist_Features(l_features_importances, l_features, titel):
    
    colors = ['steelblue', 'Indigo', 'purple', 'green', 'red']
    
    x = np.arange(len(l_features))
    fig, ax = plt.subplots()
    plt.rcParams["figure.figsize"] = [10,7]
    ax.bar(x, l_features_importances, color = colors)
    ax.set_title('Random Forest', fontweight="bold", fontsize=20)
    ax.set_ylabel('Wichtigkeit der Feature', fontsize=20)
    ax.set_xticks(x)
    ax.set_xticklabels(l_features, fontsize=26,  rotation='vertical')
           
    ax.tick_params(axis='y', which='major', labelsize=17)

    fig.tight_layout()
    plt.savefig('C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_aus_tsv/plot/classifeier/'+titel+'.pdf')

# %%
l_features = f_importances.Feature.tolist()
l_features = l_features[:5]

l_features_importances = f_importances.importance.tolist()
l_features_importances = l_features_importances[0:5]
l_features
# Out:
# ['Reputation', 'Politische P.B.', 'Moderate P.B.', 'Wissen. P.B.', 'Likes']

# %%
plot_hist_Features(l_features_importances, l_features, 'Rf_TweetsCov19_content_User_de')

# %% [markdown]
# ************************************************
# ************************************************

# %% [markdown]
# ## TweetsCov19
# ### (Nur Inhalt)

# %%
#Hier wird die Dataframe neue gebildet.
#Die Benutzerfeatuers werden entfernt.
#Die Dataframe wird in zwei Matrixen umgewandelt.

features = df_tweetscov19_user.columns
features

features = features[2:83]
df_tweetscov19_user_2 = df_tweetscov19_user[features.tolist()]
#df_tweetscov19_user_2 = df_tweetscov19_user_2.drop(columns=[ 'Moderacy p.T.'])

df = df_tweetscov19_user_2.drop('Is_deleted', axis=1)
X = df_tweetscov19_user_2.drop('Is_deleted', axis=1).values
y = df_tweetscov19_user_2['Is_deleted']

y = y.astype(int)
print(X.shape)
print(y.shape)
# Out:
# (20000, 80)
# (20000,)

# %%
#Daten werden für das Trainig und Testing aufgeteilt.
X_train, X_test, y_train, y_test= split_train_test_valid(X,y)
# Out:
# (16000, 80)
# (4000, 80)
# (16000,)
# (4000,)

# %%
# %%time
#Das Modell fiten
#Die Genuigkeit für die Testsergebnissen wird hier berechnet.
rf_model = fit_random_forest_clf(X_train, y_train)
test_random_forest_clf(rf_model, X_test, y_test)
# Out:
# Accuracy : 0.70575
# Wall time: 710 ms

# %%
#Das Modell wird hier gespeichert.
pfad_modell = 'C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_sample/Tweetscov19_sample/Modells/TweetsCov19_RF_Inhalt_all_ohne_moderacy.sav'
#pickle.dump(rf_model, open(pfad_modell, 'wb'))

# %%
#Wichtigkeit der Features wird hier bestimmt.
f_importances = features_classifier_(df, rf_model)
f_importances
# Out:
#     index                 Feature  importance
# 0       1                   Likes      0.0879
# 1       0                Retweets      0.0669
# 2       7              Lesbarkeit      0.0472
# 3       5               Textlänge      0.0435
# 4       2                Stimmung      0.0376
# 5      63             Preposition      0.0351
# 6      78                   Space      0.0267
# 7      68                    Verb      0.0253
# 8      62                 Article      0.0234
# 9      54           Focus present      0.0212
# 10     16                  Social      0.0198
# 11     21                    Work      0.0193
# 12     10         Politische P.T.      0.0191
# 13     64                 Auxverb      0.0190
# 14     66             Conjunctive      0.0176
# 15     50                   Power      0.0171
# 16     79                    Time      0.0169
# 17     69               Adjective      0.0168
# 18     61                   Ipron      0.0150
# 19      3                Hashtags      0.0146
# 20      4                Mentions      0.0139
# 21     65                  Adverb      0.0139
# 22     53              Focus past      0.0129
# 23     38               Neg. emo.      0.0123
# 24     11  Wissenschaftliche P.T.      0.0121
# 25      8               A. Emojis      0.0118
# 26     37               Pos. emo.      0.0114
# 27     70                 Compare      0.0111
# 28     47         Differentiation      0.0108
# 29     49                 Achieve      0.0108
# 30     77                  Motion      0.0107
# 31     43                   Cause      0.0104
# 32     42                 Insight      0.0103
# 33     12           Moderate P.T.      0.0101
# 34     45            Tentativness      0.0101
# 35     34                  Health      0.0100
# 36     73            Quantitative      0.0099
# 37     48             Affiliation      0.0093
# 38     14            News(Shalla)      0.0092
# 39     46               Certainty      0.0088
# 40      9         Emoji sentiment      0.0086
# 41     44                 Discrep      0.0081
# 42     51                  Reward      0.0081
# 43     52                    Risk      0.0080
# 44     71           Interrogative      0.0079
# 45     24                   Money      0.0077
# 46     58                     You      0.0076
# 47     55            Focus future      0.0072
# 48     74                     See      0.0071
# 49     60                    They      0.0069
# 50     72                  Number      0.0068
# 51      6                 URLs n.      0.0068
# 52     40                   Anger      0.0067
# 53     26                   Death      0.0066
# 54     75                    Hear      0.0064
# 55     67                  Negate      0.0064
# 56     22                 Leisure      0.0060
# 57     20                    Male      0.0057
# 58     57                      We      0.0057
# 59     59                   SheHe      0.0056
# 60     23                    Home      0.0049
# 61     39                 Anxiety      0.0048
# 62     33                    Body      0.0047
# 63     27                Informal      0.0044
# 64     41                 Sadness      0.0039
# 65     76                    Feel      0.0034
# 66     19                  Female      0.0032
# 67     56                       I      0.0029
# 68     36                  Ingest      0.0027
# 69     25                Relegion      0.0024
# 70     15       Socialnet(Shalla)      0.0023
# 71     17                  Family      0.0021
# 72     29                Netspeak      0.0020
# 73     18                  Friend      0.0019
# 74     28                   Swear      0.0016
# 75     35                  Sexual      0.0012
# 76     30                  Assent      0.0009
# 77     31              Nonfluence      0.0007
# 78     13            Porn(Shalla)      0.0003
# 79     32                  Filler      0.0002

# %%
#Anhand der Testergebnisse wird ein Bericht vorbereitet und ausgegeben.
y_pred = rf_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.70      0.70      2003
#            1       0.70      0.71      0.71      1997
#
#     accuracy                           0.71      4000
#    macro avg       0.71      0.71      0.71      4000
# weighted avg       0.71      0.71      0.71      4000

# %%
#Die Methode plot_confusion_matrix() qwird gerufen.
#Die Daten werden in Methode verarbeitet und das Confusion Matrix wird ausgegeben.
plot_confusion_matrix(y_test, y_pred, rf_model.classes_, 'Confusion Matrix')

# %%
#Hier wird wahrscheinlichkeiten der Testergebnisse berechnet.
#Anhand der bekommenen Wahrscheinlichkeiten berechnen wir das Log_loss
y_prob_test = rf_model.predict_proba(X_test)
print('Logarithmic loss für Test data', log_loss(y_test, y_prob_test))
# Out:
# Logarithmic loss für Test data 0.5840446343313292

# %%
#Das gespeicherte Modell wird geladen
pfad_modell = 'C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_sample/Tweetscov19_sample/Modells/TweetsCov19_RF_Inhalt_all_ohne_moderacy.sav'
#rf_model = pickle.load(open(pfad_modell, 'rb'))

# %%
# %%time
#Die Ergebnisse werden mithilfe der drei Metriken durch Kreuzverfahren berechnet. cv=10
print_cross_val_score(rf_model, X_test, y_test)
# Out:
#  percision : 0.70 +/- 0.015
#  f1        : 0.69 +/- 0.021
#  recall    : 0.68 +/- 0.034
# Wall time: 13.2 s

# %% [markdown]
# ********************************************************
# ********************************************************

# %% [markdown]
# ### TweetsCov19
# ### Darstellung der Wichtigkeit der Features:
# #### (Ihaltsfeatures)

# %%
def plot_hist_Features_content_only(l_features_importances, l_features, titel):
    
    colors = ['red', 'orange', 'peru', 'black', 'mediumslateblue']
    
    x = np.arange(len(l_features))

    fig, ax = plt.subplots()
    plt.rcParams["figure.figsize"] = [10,7]
    
    ax.bar(x, l_features_importances, color = colors)
    ax.set_title('Random Forest', fontweight="bold", fontsize=20)
    ax.set_ylabel('Wichtigkeit der Feature', fontsize=20)
           
    ax.tick_params(axis='y', which='major', labelsize=17)

    ax.set_xticks(x)
    ax.set_xticklabels(l_features, fontsize=26,  rotation='vertical')
    fig.tight_layout()
    

    #plt.legend()
    plt.savefig('C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_aus_tsv/plot/classifeier/'+titel+'.pdf')

# %%
l_features = f_importances.Feature.tolist()
l_features = l_features[:5]

l_features_importances = f_importances.importance.tolist()
l_features_importances = l_features_importances[0:5]
l_features
# Out:
# ['Likes', 'Retweets', 'Lesbarkeit', 'Textlänge', 'Stimmung']

# %%
plot_hist_Features_content_only(l_features_importances, l_features, 'Rf_TweetsCov19_content_only_de')

# %% [markdown]
# ************************************************
# ************************************************

# %% [markdown]
# # *(2)Tweetskb*
# ### (Inhalt- und Benutzerfeatures)

# %%
#Die Dataframe, die sowohl die Benutzer- als auch die Inhaltsfeatures enthält, wird gelesen.
pfad_tsv = 'C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_sample/Tweetskb_sample/TweetsFormodel/tweetskb_sample_with_users_1_51.tsv'

df_tweetskb_user = pd.read_csv(pfad_tsv, sep='\t', error_bad_lines=False, names=['Tweet_Id', 'Username', 'Is_deleted', 'Retweets', 'Likes', 'Stimmung', 'Hashtags', 'Mentions', 'Textlänge', 'URLs n.', 'Lesbarkeit', 'A. Emojis', 'Emoji sentiment', 'Politische P.T.', 'Wissenschaftliche P.T.', 'Moderate P.T.', 'Porn(Shalla)', 'News(Shalla)', 'Socialnet(Shalla)', 'Social', 'Family', 'Friend', 'Female', 'Male' , 'Work', 'Leisure', 'Home', 'Money', 'Relegion', 'Death', 'Informal', 'Swear', 'Netspeak', 'Assent', 'Nonfluence', 'Filler', 'Body', 'Health', 'Sexual', 'Ingest', 'Pos. emo.', 'Neg. emo.', 'Anxiety', 'Anger', 'Sadness', 'Insight', 'Cause', 'Discrep', 'Tentativness', 'Certainty', 'Differentiation', 'Affiliation', 'Achieve', 'Power', 'Reward', 'Risk', 'Focus past', 'Focus present', 'Focus future', 'I', 'We', 'You', 'SheHe', 'They', 'Ipron', 'Article', 'Preposition', 'Auxverb', 'Adverb', 'Conjunctive', 'Negate', 'Verb', 'Adjective', 'Compare', 'Interrogative', 'Number', 'Quantitative', 'See', 'Hear', 'Feel', 'Motion', 'Space', 'Time', 'Politische P.B.', 'Wissen. P.B.', 'Moderate P.B.', 'Posted n.', 'Deleted n.', 'Deletion ratio', 'Reputation' ])
pd.options.display.max_columns = None
print('Shape :', df_tweetskb_user.shape)
df_tweetskb_user.head()
# Out:
# Shape : (20000, 90)
#               Tweet_Id         Username  Is_deleted  Retweets  Likes  \
# 0  1250809251561263111         X14Eagle        True         9     20
# 1  1261189358176145408     battleofever        True        50     63
# 2  1250125070472597504    LastStand2019        True         0      0
# 3  1254147529668726790  TRUMPMOVEMENTUS        True         0      0
# 4  1248292934316748802          wdunlap        True         9     21
#
#    Stimmung  Hashtags  Mentions  Textlänge  URLs n.  Lesbarkeit  A. Emojis  \
# 0    0.9738         0         1        106        0     82.7570          6
# 1   -0.4469         6         2        303        0     72.6330          4
# 2   -0.8025         0         0        227        1     92.6370          0
# 3    0.5859         0         0        117        1     66.5280          0
# 4   -0.4199         1         0        320        0     36.6350          0
#
#    Emoji sentiment  Politische P.T.  Wissenschaftliche P.T.  Moderate P.T.  \
# 0           0.5710                0                       0              0
# 1           0.1847                0                       0              0
# 2           0.0000                1                      -1              0
# 3           0.0000                0                       0              1
# 4           0.0000                0                       0              0
#
#    Porn(Shalla)  News(Shalla)  Socialnet(Shalla)  Social  Family  Friend  \
# 0        0.0000        0.0000             0.0000 13.3300  0.0000  0.0000
# 1        0.0000        0.0000             0.0000  8.1600  0.0000  0.0000
# 2        0.0000        0.0000             0.0000 14.6300  0.0000  0.0000
# 3        0.0000        0.0000             0.0000  0.0000  0.0000  0.0000
# 4        0.0000        0.0000             0.0000  0.0000  0.0000  0.0000
#
#    Female   Male   Work  Leisure   Home  Money  Relegion  Death  Informal  \
# 0  0.0000 0.0000 0.0000  13.3300 0.0000 0.0000    0.0000 0.0000    0.0000
# 1  0.0000 4.0800 0.0000   0.0000 0.0000 0.0000    4.0800 0.0000    2.0400
# 2  0.0000 7.3200 0.0000   0.0000 0.0000 2.4400    0.0000 0.0000    0.0000
# 3  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000
# 4  0.0000 0.0000 1.8900   0.0000 0.0000 0.0000    0.0000 0.0000    0.0000
#
#    Swear  Netspeak  Assent  Nonfluence  Filler   Body  Health  Sexual  Ingest  \
# 0 0.0000    0.0000  0.0000      0.0000  0.0000 6.6700  0.0000  0.0000  0.0000
# 1 2.0400    0.0000  0.0000      0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
# 2 0.0000    0.0000  0.0000      0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
# 3 0.0000    0.0000  0.0000      0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
# 4 0.0000    0.0000  0.0000      0.0000  0.0000 0.0000  0.0000  0.0000  0.0000
#
#    Pos. emo.  Neg. emo.  Anxiety  Anger  Sadness  Insight  Cause  Discrep  \
# 0     0.0000     0.0000   0.0000 0.0000   0.0000   0.0000 0.0000   0.0000
# 1     2.0400     6.1200   0.0000 6.1200   0.0000   0.0000 0.0000   0.0000
# 2     2.4400     2.4400   0.0000 2.4400   0.0000   2.4400 0.0000   0.0000
# 3     0.0000     0.0000   0.0000 0.0000   0.0000   0.0000 0.0000   0.0000
# 4     0.0000     1.8900   0.0000 1.8900   0.0000   1.8900 0.0000   0.0000
#
#    Tentativness  Certainty  Differentiation  Affiliation  Achieve  Power  \
# 0        0.0000     0.0000           6.6700      13.3300   0.0000 0.0000
# 1        0.0000     0.0000           0.0000       2.0400   0.0000 0.0000
# 2        0.0000     2.4400           0.0000       2.4400   0.0000 0.0000
# 3        0.0000     0.0000           0.0000       0.0000   0.0000 0.0000
# 4        0.0000     0.0000           0.0000       0.0000   0.0000 5.6600
#
#    Reward   Risk  Focus past  Focus present  Focus future      I     We  \
# 0  0.0000 0.0000      0.0000         0.0000        0.0000 0.0000 0.0000
# 1  0.0000 0.0000      2.0400         6.1200        0.0000 0.0000 2.0400
# 2  2.4400 0.0000      2.4400         4.8800        0.0000 0.0000 0.0000
# 3  0.0000 0.0000      0.0000         0.0000        0.0000 0.0000 0.0000
# 4  0.0000 0.0000      0.0000         0.0000        0.0000 0.0000 0.0000
#
#      You  SheHe   They  Ipron  Article  Preposition  Auxverb  Adverb  \
# 0 0.0000 0.0000 0.0000 0.0000   6.6700       6.6700   0.0000  0.0000
# 1 0.0000 0.0000 0.0000 4.0800   2.0400      10.2000   8.1600  0.0000
# 2 0.0000 7.3200 0.0000 7.3200   2.4400       7.3200   9.7600  0.0000
# 3 0.0000 0.0000 0.0000 0.0000   0.0000       5.5600   0.0000  0.0000
# 4 0.0000 0.0000 0.0000 0.0000   9.4300      15.0900   1.8900  3.7700
#
#    Conjunctive  Negate    Verb  Adjective  Compare  Interrogative  Number  \
# 0       0.0000  0.0000  0.0000     0.0000   0.0000         0.0000  0.0000
# 1       4.0800  0.0000 10.2000     4.0800   4.0800         0.0000  0.0000
# 2       2.4400  2.4400 19.5100     0.0000   2.4400         2.4400  0.0000
# 3       0.0000  0.0000  0.0000     0.0000   0.0000         0.0000  0.0000
# 4       3.7700  0.0000  1.8900     3.7700   3.7700         0.0000  0.0000
#
#    Quantitative    See   Hear   Feel  Motion   Space   Time  Politische P.B.  \
# 0        0.0000 0.0000 6.6700 0.0000  6.6700  6.6700 0.0000           0.2000
# 1        0.0000 0.0000 2.0400 0.0000  0.0000  6.1200 0.0000           0.6000
# 2        0.0000 0.0000 0.0000 0.0000  0.0000  0.0000 2.4400           1.0000
# 3        0.0000 0.0000 0.0000 0.0000  0.0000  0.0000 0.0000           0.6667
# 4        0.0000 0.0000 0.0000 0.0000  1.8900 11.3200 7.5500           0.6000
#
#    Wissen. P.B.  Moderate P.B.  Posted n.  Deleted n.  Deletion ratio  \
# 0       -1.0000        -1.0000         16          16          1.0000
# 1       -0.1667         0.4286         39          39          1.0000
# 2       -1.0000         1.0000         28          28          1.0000
# 3       -0.6667         0.4286         32          32          1.0000
# 4       -0.1429         0.4545         65          21          0.3231
#
#    Reputation
# 0      0.4777
# 1      0.4909
# 2      0.5017
# 3      0.6114
# 4      0.5021

# %%
#Features von Dataframe werden ausgewählt.
features = df_tweetskb_user.columns

# %%
#Die gelöscten Tweets werden mit 0 und nicht gelösschten mit 1 markiert.
df_tweetskb_user['Is_deleted'] = np.where(df_tweetskb_user['Is_deleted'] == True, 0, 1)
df_tweetskb_user.tail()
# Out:
#                   Tweet_Id         Username  Is_deleted  Retweets  Likes  \
# 19995  1215952769003270145   gumboqueen3030           1         1      1
# 19996  1209466108937482241  AnnaApp91838450           1        93    186
# 19997  1193214074835746817   ChloeSalsameda           1        25     29
# 19998  1257815607522852864      seanhannity           1       185    342
# 19999  1187064689299283969    DrDenaGrayson           1      1088   2701
#
#        Stimmung  Hashtags  Mentions  Textlänge  URLs n.  Lesbarkeit  \
# 19995    0.0000         0         2        125        0     87.3000
# 19996   -0.6800         0         1        298        0    -15.0030
# 19997    0.0772         1         0        194        0     44.1670
# 19998    0.0000         0         0         80        1     67.7550
# 19999   -0.7794         3         3        291        1     41.5540
#
#        A. Emojis  Emoji sentiment  Politische P.T.  Wissenschaftliche P.T.  \
# 19995          0           0.0000                0                       0
# 19996          4           0.3038                0                       0
# 19997          0           0.0000                0                       0
# 19998          0           0.0000                0                       0
# 19999          1           0.4930                0                       0
#
#        Moderate P.T.  Porn(Shalla)  News(Shalla)  Socialnet(Shalla)  Social  \
# 19995              0        0.0000        0.0000             0.0000  9.5200
# 19996              0        0.0000        0.0000             0.0000  2.7800
# 19997              0        0.0000        0.0000             0.0000 10.7100
# 19998              0        0.0000        0.0000             0.0000  0.0000
# 19999              0        0.0000        0.0000             1.0000  6.8200
#
#        Family  Friend  Female   Male   Work  Leisure   Home  Money  Relegion  \
# 19995  0.0000  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000
# 19996  0.0000  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000
# 19997  0.0000  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000
# 19998  0.0000  0.0000  0.0000 0.0000 0.0000   0.0000 0.0000 0.0000    0.0000
# 19999  0.0000  0.0000  0.0000 2.2700 2.2700   0.0000 0.0000 0.0000    0.0000
#
#        Death  Informal  Swear  Netspeak  Assent  Nonfluence  Filler   Body  \
# 19995 0.0000    0.0000 0.0000    0.0000  0.0000      0.0000  0.0000 0.0000
# 19996 0.0000    0.0000 0.0000    0.0000  0.0000      0.0000  0.0000 0.0000
# 19997 0.0000    0.0000 0.0000    0.0000  0.0000      0.0000  0.0000 0.0000
# 19998 0.0000    0.0000 0.0000    0.0000  0.0000      0.0000  0.0000 0.0000
# 19999 0.0000    0.0000 0.0000    0.0000  0.0000      0.0000  0.0000 0.0000
#
#        Health  Sexual  Ingest  Pos. emo.  Neg. emo.  Anxiety  Anger  Sadness  \
# 19995  0.0000  0.0000  0.0000     0.0000     0.0000   0.0000 0.0000   0.0000
# 19996  0.0000  0.0000  0.0000     2.7800     0.0000   0.0000 0.0000   0.0000
# 19997  0.0000  0.0000  0.0000     0.0000     0.0000   0.0000 0.0000   0.0000
# 19998  0.0000  0.0000  0.0000     0.0000     0.0000   0.0000 0.0000   0.0000
# 19999  0.0000  0.0000  0.0000     0.0000     2.2700   2.2700 0.0000   0.0000
#
#        Insight  Cause  Discrep  Tentativness  Certainty  Differentiation  \
# 19995   0.0000 0.0000   4.7600        4.7600     0.0000           9.5200
# 19996   0.0000 0.0000   0.0000        0.0000     2.7800           0.0000
# 19997   0.0000 0.0000   3.5700        0.0000     0.0000           0.0000
# 19998   0.0000 0.0000   0.0000        0.0000     0.0000           0.0000
# 19999   2.2700 2.2700   4.5500        0.0000     2.2700           0.0000
#
#        Affiliation  Achieve  Power  Reward   Risk  Focus past  Focus present  \
# 19995       4.7600   0.0000 0.0000  4.7600 0.0000      4.7600         9.5200
# 19996       0.0000   0.0000 0.0000  2.7800 0.0000      0.0000         0.0000
# 19997       0.0000   0.0000 3.5700  0.0000 0.0000      0.0000         7.1400
# 19998       0.0000   0.0000 0.0000  0.0000 0.0000      0.0000         0.0000
# 19999       0.0000   4.5500 2.2700  0.0000 0.0000      2.2700         9.0900
#
#        Focus future      I     We    You  SheHe   They  Ipron  Article  \
# 19995        4.7600 0.0000 4.7600 0.0000 0.0000 4.7600 4.7600   0.0000
# 19996        0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 2.7800   0.0000
# 19997        0.0000 0.0000 0.0000 0.0000 0.0000 3.5700 0.0000   7.1400
# 19998        0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000   0.0000
# 19999        0.0000 0.0000 0.0000 0.0000 2.2700 0.0000 4.5500   6.8200
#
#        Preposition  Auxverb  Adverb  Conjunctive  Negate    Verb  Adjective  \
# 19995       9.5200  14.2900  4.7600       9.5200  0.0000 19.0500     0.0000
# 19996       5.5600   0.0000  0.0000       0.0000  0.0000  0.0000     0.0000
# 19997      10.7100   0.0000  0.0000       0.0000  0.0000  7.1400     0.0000
# 19998       6.6700   0.0000  0.0000       0.0000  0.0000  0.0000     0.0000
# 19999       6.8200  11.3600  2.2700       6.8200  0.0000 13.6400     2.2700
#
#        Compare  Interrogative  Number  Quantitative    See   Hear   Feel  \
# 19995   0.0000         0.0000  0.0000        4.7600 0.0000 0.0000 0.0000
# 19996   0.0000         0.0000  0.0000        0.0000 0.0000 0.0000 0.0000
# 19997   0.0000         0.0000  0.0000        0.0000 0.0000 0.0000 0.0000
# 19998   0.0000         0.0000  0.0000        0.0000 0.0000 0.0000 0.0000
# 19999   2.2700         0.0000  0.0000        0.0000 0.0000 2.2700 0.0000
#
#        Motion  Space   Time  Politische P.B.  Wissen. P.B.  Moderate P.B.  \
# 19995  0.0000 4.7600 4.7600          -0.0370       -0.6667        -0.4118
# 19996  0.0000 2.7800 0.0000           0.4737       -0.9167         0.2857
# 19997  0.0000 3.5700 0.0000          -0.2000       -1.0000        -1.0000
# 19998  0.0000 6.6700 0.0000          -0.1111       -0.5000        -0.6000
# 19999  2.2700 2.2700 0.0000          -0.3000        1.0000        -0.5789
#
#        Posted n.  Deleted n.  Deletion ratio  Reputation
# 19995         37           0          0.0000      0.4823
# 19996         81           0          0.0000      0.6074
# 19997         32           0          0.0000      0.9808
# 19998        218           2          0.0092      1.0000
# 19999        160           3          0.0187      0.9982

# %%
#TweetId und Benutzername werden aus der Dataframe entfernt.
features = features[2:90]
print(len(features))
features
# Out:
# 88
# Index(['Is_deleted', 'Retweets', 'Likes', 'Stimmung', 'Hashtags', 'Mentions',
#        'Textlänge', 'URLs n.', 'Lesbarkeit', 'A. Emojis', 'Emoji sentiment',
#        'Politische P.T.', 'Wissenschaftliche P.T.', 'Moderate P.T.',
#        'Porn(Shalla)', 'News(Shalla)', 'Socialnet(Shalla)', 'Social', 'Family',
#        'Friend', 'Female', 'Male', 'Work', 'Leisure', 'Home', 'Money',
#        'Relegion', 'Death', 'Informal', 'Swear', 'Netspeak', 'Assent',
#        'Nonfluence', 'Filler', 'Body', 'Health', 'Sexual', 'Ingest',
#        'Pos. emo.', 'Neg. emo.', 'Anxiety', 'Anger', 'Sadness', 'Insight',
#        'Cause', 'Discrep', 'Tentativness', 'Certainty', 'Differentiation',
#        'Affiliation', 'Achieve', 'Power', 'Reward', 'Risk', 'Focus past',
#        'Focus present', 'Focus future', 'I', 'We', 'You', 'SheHe', 'They',
#        'Ipron', 'Article', 'Preposition', 'Auxverb', 'Adverb', 'Conjunctive',
#        'Negate', 'Verb', 'Adjective', 'Compare', 'Interrogative', 'Number',
#        'Quantitative', 'See', 'Hear', 'Feel', 'Motion', 'Space', 'Time',
#        'Politische P.B.', 'Wissen. P.B.', 'Moderate P.B.', 'Posted n.',
#        'Deleted n.', 'Deletion ratio', 'Reputation'],
#       dtype='object')

# %%
# Die Features, Anzahl der geposteten und gelöschten Tweets sowie Löschquote werden hier aus der Dataframe entfernt.
#Zwei Matrixen werden erzeugt. Einer beinhaltet alle Features ohne 'Ist_gelöscht' und die Andere nur 'Ist_gelöscht' 

df_tweetskb_user_2 = df_tweetskb_user[features.tolist()]
df_tweetskb_user_2 = df_tweetskb_user_2.drop(columns=['Posted n.', 'Deleted n.', 'Deletion ratio'])
df = df_tweetskb_user_2.drop('Is_deleted', axis=1)
X = df_tweetskb_user_2.drop('Is_deleted', axis=1).values
y = df_tweetskb_user_2['Is_deleted']

y = y.astype(int)
print(X.shape)
print(y.shape)
# Out:
# (20000, 84)
# (20000,)

# %%
#Hier werden die Daten in zwei Teielen für das Training und den Testing des Modells aufgeteilt.
X_train, X_test, y_train, y_test = split_train_test_valid(X,y)
# Out:
# (16000, 84)
# (4000, 84)
# (16000,)
# (4000,)

# %%
# %%time
#Das Modell fiten
#Die Genuigkeit für die Testsergebnissen wird hier berechnet.
rf_model = fit_random_forest_clf(X_train, y_train)
test_random_forest_clf(rf_model, X_test, y_test)
# Out:
# Accuracy : 0.81325
# Wall time: 741 ms

# %%
#Das Modell wird gespeichert.
pfad_modell = 'C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_sample/Tweetskb_sample/Modells/TweetsKB_RF_Benutzer_Inhalt_alle_ohne_moderacy.sav'
#pickle.dump(rf_model, open(pfad_modell, 'wb'))

# %%
#Anhand der Testergebnisse wird ein Bericht vorbereitet und ausgegeben.
y_pred = rf_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.86      0.82      2003
#            1       0.84      0.77      0.80      1997
#
#     accuracy                           0.81      4000
#    macro avg       0.82      0.81      0.81      4000
# weighted avg       0.82      0.81      0.81      4000

# %%
#Wichtigkeit der Features werden hier berechnet.
f_importances = features_classifier_(df, rf_model)
f_importances
# Out:
#     index                 Feature  importance
# 0      83              Reputation      0.1407
# 1      80         Politische P.B.      0.1256
# 2      81            Wissen. P.B.      0.0706
# 3      82           Moderate P.B.      0.0611
# 4       1                   Likes      0.0366
# 5       5               Textlänge      0.0313
# 6       7              Lesbarkeit      0.0296
# 7       0                Retweets      0.0275
# 8       2                Stimmung      0.0268
# 9      63             Preposition      0.0221
# 10     78                   Space      0.0169
# 11     62                 Article      0.0151
# 12     68                    Verb      0.0148
# 13     54           Focus present      0.0133
# 14     10         Politische P.T.      0.0128
# 15     16                  Social      0.0127
# 16     64                 Auxverb      0.0118
# 17      4                Mentions      0.0107
# 18     50                   Power      0.0102
# 19     66             Conjunctive      0.0102
# 20     61                   Ipron      0.0100
# 21     69               Adjective      0.0098
# 22     79                    Time      0.0097
# 23     21                    Work      0.0096
# 24      8               A. Emojis      0.0096
# 25     65                  Adverb      0.0089
# 26     38               Neg. emo.      0.0084
# 27      9         Emoji sentiment      0.0082
# 28     53              Focus past      0.0080
# 29     37               Pos. emo.      0.0076
# 30      3                Hashtags      0.0073
# 31     77                  Motion      0.0073
# 32     42                 Insight      0.0070
# 33     70                 Compare      0.0068
# 34     46               Certainty      0.0065
# 35     47         Differentiation      0.0063
# 36     43                   Cause      0.0062
# 37     48             Affiliation      0.0061
# 38     73            Quantitative      0.0060
# 39     45            Tentativness      0.0059
# 40     49                 Achieve      0.0057
# 41     12           Moderate P.T.      0.0055
# 42     44                 Discrep      0.0054
# 43     24                   Money      0.0051
# 44     51                  Reward      0.0051
# 45     11  Wissenschaftliche P.T.      0.0050
# 46     58                     You      0.0048
# 47     71           Interrogative      0.0048
# 48     40                   Anger      0.0047
# 49     59                   SheHe      0.0046
# 50     20                    Male      0.0046
# 51     55            Focus future      0.0045
# 52      6                 URLs n.      0.0045
# 53     74                     See      0.0043
# 54     67                  Negate      0.0042
# 55     72                  Number      0.0040
# 56     14            News(Shalla)      0.0040
# 57     60                    They      0.0039
# 58     22                 Leisure      0.0039
# 59     52                    Risk      0.0037
# 60     34                  Health      0.0037
# 61     57                      We      0.0037
# 62     75                    Hear      0.0036
# 63     23                    Home      0.0034
# 64     19                  Female      0.0032
# 65     27                Informal      0.0030
# 66     33                    Body      0.0029
# 67     41                 Sadness      0.0028
# 68     26                   Death      0.0027
# 69     56                       I      0.0026
# 70     39                 Anxiety      0.0024
# 71     15       Socialnet(Shalla)      0.0023
# 72     17                  Family      0.0021
# 73     76                    Feel      0.0017
# 74     18                  Friend      0.0017
# 75     36                  Ingest      0.0017
# 76     28                   Swear      0.0016
# 77     29                Netspeak      0.0016
# 78     25                Relegion      0.0016
# 79     35                  Sexual      0.0015
# 80     30                  Assent      0.0012
# 81     31              Nonfluence      0.0005
# 82     32                  Filler      0.0003
# 83     13            Porn(Shalla)      0.0000

# %%
#Die Methode plot_confusion_matrix() qwird gerufen.
#Die Daten werden in Methode verarbeitet und das Confusion Matrix wird ausgegeben.
plot_confusion_matrix(y_test, y_pred, rf_model.classes_, 'Confusion Matrix')

# %%
#Hier wird wahrscheinlichkeiten der Ergebnisse berechnet.
#Anhand der bekommenen Wahrscheinlichkeiten berechnen wir das Log_loss
y_prob_test = rf_model.predict_proba(X_test)
print('Logarithmic loss für Test data', log_loss(y_test, y_prob_test))
# Out:
# Logarithmic loss für Test data 0.44672582509864744

# %%
#Das Modell kann man hier laden
pfad_model = 'C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_sample/Tweetskb_sample/Modells/TweetsKB_RF_Benutzer_Inhalt_alle_ohne_moderacy.sav'
#rf_modell = pickle.load(open(pfad_modell, 'rb'))

# %%
#Die Ergebnisse werden mithilfe der drei Metriken durch Kreuzverfahren berechnet. cv=10
print_cross_val_score(rf_model, X_test, y_test)
# Out:
#  percision : 0.80 +/- 0.022
#  f1        : 0.78 +/- 0.018
#  recall    : 0.76 +/- 0.025

# %% [markdown]
# *****************************************************
# *****************************************************

# %% [markdown]
# ### TweetsKB
# ### Darstellung der Wichtigkeit der Features:
# #### (Ihalt- udn Benutzerfeatures)

# %%
def plot_hist_Features_kb(l_features_importances, l_features, titel):
    
    colors = ['steelblue','Indigo', 'green', 'purple', 'red']
    
    x = np.arange(len(l_features))
    fig, ax = plt.subplots()
    plt.rcParams["figure.figsize"] = [10,7]
    
    ax.bar(x, l_features_importances, color = colors)
    ax.set_title('Random Forest', fontweight="bold", fontsize=20)
    ax.set_ylabel('Wichtigkeit der Feature', fontsize=20)
    ax.set_xticks(x)
    ax.set_xticklabels(l_features, fontsize=26,  rotation='vertical')
           
    ax.tick_params(axis='y', which='major', labelsize=17)

    fig.tight_layout()
    plt.savefig('C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_aus_tsv/plot/classifeier/'+titel+'.pdf')

# %%
l_features = f_importances.Feature.tolist()
l_features = l_features[:5]

l_features_importances = f_importances.importance.tolist()
l_features_importances = l_features_importances[0:5]
l_features
# Out:
# ['Reputation', 'Politische P.B.', 'Wissen. P.B.', 'Moderate P.B.', 'Likes']

# %%
plot_hist_Features_kb(l_features_importances, l_features, 'Rf_Tweetskb_content_User_de')

# %% [markdown]
# ***********************************************************************
# ***********************************************************************

# %% [markdown]
# ## Tweetskb
# ### Nur Inhalt

# %%
#Hier wird die Dataframe neu gebildet.
#Die Benutzerfeatuers werden entfernt.
#Die Datframe wird in zwei Matrixen umgewandelt.
features = df_tweetskb_user.columns
features

features = features[2:83]
df_tweetskb_user_2 = df_tweetskb_user[features.tolist()]
#df_tweetskb_user_2 = df_tweetskb_user_2.drop(columns=['Moderacy p.T.'])

df = df_tweetskb_user_2.drop('Is_deleted', axis=1)

X = df_tweetskb_user_2.drop('Is_deleted', axis=1).values
y = df_tweetskb_user_2['Is_deleted']

y = y.astype(int)
print(X.shape)
print(y.shape)
# Out:
# (20000, 80)
# (20000,)

# %%
#Daten werden für das Trainig und Testing des Modells aufgeteilt.
X_train, X_test, y_train, y_test = split_train_test_valid(X,y)
# Out:
# (16000, 80)
# (4000, 80)
# (16000,)
# (4000,)

# %%
# %%time
#Das Modell wird hier gefitet
#Die Genuigkeit für die Testsergebnissen wird berechnet.
rf_model = fit_random_forest_clf(X_train, y_train)
test_random_forest_clf(rf_model, X_test, y_test)
# Out:
# Accuracy : 0.662
# Wall time: 701 ms

# %%
#Das Modell wird hier gespeichert
pfad_modell = 'C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_sample/Tweetskb_sample/Modells/TweetsKB_RF_Inhalt_alle_ohne_moderacy.sav'
#pickle.dump(rf_model, open(pfad_modell, 'wb'))

# %%
#Wichtigkeit der Features wird hier bestimmt.
f_importances = features_classifier_(df, rf_model)
f_importances
# Out:
#     index                 Feature  importance
# 0       1                   Likes      0.0809
# 1       5               Textlänge      0.0566
# 2       7              Lesbarkeit      0.0544
# 3       0                Retweets      0.0529
# 4       2                Stimmung      0.0465
# 5      63             Preposition      0.0367
# 6      78                   Space      0.0283
# 7      62                 Article      0.0246
# 8      68                    Verb      0.0240
# 9      10         Politische P.T.      0.0222
# 10     54           Focus present      0.0204
# 11     16                  Social      0.0204
# 12      4                Mentions      0.0186
# 13     64                 Auxverb      0.0185
# 14     66             Conjunctive      0.0174
# 15      8               A. Emojis      0.0171
# 16     50                   Power      0.0166
# 17     21                    Work      0.0165
# 18     79                    Time      0.0156
# 19     69               Adjective      0.0154
# 20     61                   Ipron      0.0148
# 21     65                  Adverb      0.0142
# 22      9         Emoji sentiment      0.0137
# 23     38               Neg. emo.      0.0129
# 24     53              Focus past      0.0123
# 25     37               Pos. emo.      0.0122
# 26      3                Hashtags      0.0119
# 27     70                 Compare      0.0107
# 28     77                  Motion      0.0103
# 29     42                 Insight      0.0102
# 30     12           Moderate P.T.      0.0100
# 31     47         Differentiation      0.0099
# 32     43                   Cause      0.0098
# 33     73            Quantitative      0.0092
# 34     48             Affiliation      0.0091
# 35     45            Tentativness      0.0091
# 36     49                 Achieve      0.0091
# 37     46               Certainty      0.0090
# 38     14            News(Shalla)      0.0084
# 39     44                 Discrep      0.0079
# 40     71           Interrogative      0.0075
# 41     55            Focus future      0.0075
# 42     11  Wissenschaftliche P.T.      0.0074
# 43     51                  Reward      0.0074
# 44     24                   Money      0.0073
# 45     58                     You      0.0072
# 46     40                   Anger      0.0071
# 47     20                    Male      0.0070
# 48     59                   SheHe      0.0067
# 49     72                  Number      0.0067
# 50     52                    Risk      0.0065
# 51     67                  Negate      0.0065
# 52      6                 URLs n.      0.0065
# 53     74                     See      0.0064
# 54     22                 Leisure      0.0060
# 55     60                    They      0.0059
# 56     75                    Hear      0.0058
# 57     57                      We      0.0052
# 58     34                  Health      0.0051
# 59     27                Informal      0.0047
# 60     23                    Home      0.0047
# 61     33                    Body      0.0042
# 62     19                  Female      0.0041
# 63     26                   Death      0.0040
# 64     41                 Sadness      0.0037
# 65     15       Socialnet(Shalla)      0.0037
# 66     39                 Anxiety      0.0036
# 67     56                       I      0.0035
# 68     76                    Feel      0.0028
# 69     36                  Ingest      0.0024
# 70     18                  Friend      0.0023
# 71     17                  Family      0.0023
# 72     25                Relegion      0.0021
# 73     29                Netspeak      0.0021
# 74     28                   Swear      0.0019
# 75     35                  Sexual      0.0017
# 76     30                  Assent      0.0012
# 77     31              Nonfluence      0.0008
# 78     32                  Filler      0.0002
# 79     13            Porn(Shalla)      0.0000

# %%
#Anhand der Testergebnisse wird hier ein Bericht vorbereitet und ausgegeben.
y_pred = rf_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.69      0.67      2003
#            1       0.67      0.64      0.65      1997
#
#     accuracy                           0.66      4000
#    macro avg       0.66      0.66      0.66      4000
# weighted avg       0.66      0.66      0.66      4000

# %%
#Die Methode plot_confusion_matrix() wird gerufen.
#Die Daten werden in Methode verarbeitet und das Confusion Matrix wird ausgegeben.
plot_confusion_matrix(y_test, y_pred, rf_model.classes_, 'Confusion Matrix')

# %%
#Hier wird wahrscheinlichkeiten für die Ergebnisse berechnet.
#Anhand der bekommenen Wahrscheinlichkeiten berechnen wir das Log_loss
y_prob_test = rf_model.predict_proba(X_test)
print('Logarithmic loss für Test data', log_loss(y_test, y_prob_test))
# Out:
# Logarithmic loss für Test data 0.6118679828688888

# %%
pfad_modell = 'C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_sample/Tweetskb_sample/Modells/TweetsKB_RF_Inhalt_alle_ohne_moderacy.sav'
#rf_regression = pickle.load(open(pfad_modell, 'rb'))

# %%
# %%time
#Die Ergebnisse werden mithilfe der drei Metriken durch Kreuzverfahren berechnet. cv=10

print_cross_val_score(rf_model, X_test, y_test)
# Out:
#  percision : 0.66 +/- 0.024
#  f1        : 0.64 +/- 0.026
#  recall    : 0.63 +/- 0.034
# Wall time: 13.3 s

# %% [markdown]
# ***************************************************
# ***************************************************

# %% [markdown]
# ### Darstellung der Wichtigkeit der Features:
# #### TweetsKB
# #### (Ihaltsfeatures)

# %%
def plot_hist_Features_content_only_kb(l_features_importances, l_features, titel):
    
    colors = ['red', 'black', 'peru', 'orange', 'mediumslateblue']
    
    x = np.arange(len(l_features))
    fig, ax = plt.subplots()
    plt.rcParams["figure.figsize"] = [10,7]
    
    ax.bar(x, l_features_importances, color = colors)
    ax.set_title('Random Forest', fontweight="bold", fontsize=20)
    ax.set_ylabel('Wichtigkeit der Feature', fontsize=20)
    ax.set_xticks(x)
    ax.set_xticklabels(l_features, fontsize=26,  rotation='vertical')
           
    ax.tick_params(axis='y', which='major', labelsize=17)

    fig.tight_layout()
 
    #plt.legend()
    plt.savefig('C:/Mo/tweetDB/tweetscov19/TweetsCov19_tsv/data_aus_tsv/plot/classifeier/'+titel+'.pdf')

# %%
l_features = f_importances.Feature.tolist()
l_features = l_features[:5]

l_features_importances = f_importances.importance.tolist()
l_features_importances = l_features_importances[0:5]
l_features
# Out:
# ['Likes', 'Textlänge', 'Lesbarkeit', 'Retweets', 'Stimmung']

# %%
plot_hist_Features_content_only_kb(l_features_importances, l_features, 'Rf_Tweetskb_content_only_de')
